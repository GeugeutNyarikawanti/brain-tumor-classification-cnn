# %% [markdown]
# # 1. Import Library

# %%
import sys
from pathlib import Path

import torch
import torch.nn as nn

PROJECT_ROOT = Path("..").resolve()

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from settings.config import *

# %% [markdown]
# # 2. Configuration Check

# %%
print(f"Image Size : {IMAGE_SIZE}")
print(f"Batch Size : {BATCH_SIZE}")
print(f"Classes    : {NUM_CLASSES}")
# Out:
# Image Size : 224
# Batch Size : 64
# Classes    : 4

# %% [markdown]
# # 3. CNN

# %%
from Models.cnn import BrainTumorCNN

# %%
model = BrainTumorCNN()

print(model)
# Out:
# BrainTumorCNN(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=100352, out_features=256, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=256, out_features=4, bias=True)
#   )
# )

# %%
import importlib
import Utils.data_loader as dl

importlib.reload(dl)

train_loader, test_loader = dl.create_dataloaders()

# %%
images, labels = next(iter(train_loader))

outputs = model(images)

print(images.shape)
print(labels.shape)
print(outputs.shape)
# Out:
# torch.Size([64, 3, 224, 224])
# torch.Size([64])
# torch.Size([64, 4])

# %% [markdown]
# # 4. Summary

# %%
from torchinfo import summary

summary(
    model=model,
    input_size=(BATCH_SIZE, 3, IMAGE_SIZE, IMAGE_SIZE),
    col_names=["input_size", "output_size", "num_params"],
    verbose=1
)
# Out:
# ===================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #
# ===================================================================================================================
# BrainTumorCNN                            [64, 3, 224, 224]         [64, 4]                   --
# ├─Sequential: 1-1                        [64, 3, 224, 224]         [64, 128, 28, 28]         --
# │    └─Conv2d: 2-1                       [64, 3, 224, 224]         [64, 32, 224, 224]        896
# │    └─BatchNorm2d: 2-2                  [64, 32, 224, 224]        [64, 32, 224, 224]        64
# │    └─ReLU: 2-3                         [64, 32, 224, 224]        [64, 32, 224, 224]        --
# │    └─MaxPool2d: 2-4                    [64, 32, 224, 224]        [64, 32, 112, 112]        --
# │    └─Conv2d: 2-5                       [64, 32, 112, 112]        [64, 64, 112, 112]        18,496
# │    └─BatchNorm2d: 2-6                  [64, 64, 112, 112]        [64, 64, 112, 112]        128
# │    └─ReLU: 2-7                         [64, 64, 112, 112]        [64, 64, 112, 112]        --
# │    └─MaxPool2d: 2-8                    [64, 64, 112, 112]        [64, 64, 56, 56]          --
# │    └─Conv2d: 2-9                       [64, 64, 56, 56]          [64, 128, 56, 56]         73,856
# │    └─ReLU: 2-10                        [64, 128, 56, 56]         [64, 128, 56, 56]         --
# │    └─BatchNorm2d: 2-11                 [64, 128, 56, 56]         [64, 128, 56, 56]         256
# │    └─MaxPool2d: 2-12                   [64, 128, 56, 56]         [64, 128, 28, 28]         --
# ├─Sequential: 1-2                        [64, 128, 28, 28]         [64, 4]                   --
# │    └─Flatten: 2-13                     [64, 128, 28, 28]         [64, 100352]              --
# │    └─Linear: 2-14                      [64, 100352]              [64, 256]                 25,690,368
# │    └─ReLU: 2-15                        [64, 256]                 [64, 256]                 --
# │    └─Dropout: 2-16                     [64, 256]                 [64, 256]                 --
# │    └─Linear: 2-17                      [64, 256]                 [64, 4]                   1,028
# ===================================================================================================================
# Total params: 25,785,092
# Trainable params: 25,785,092
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 34.19
# ===================================================================================================================
# Input size (MB): 38.54
# Forward/backward pass size (MB): 2877.43
# Params size (MB): 103.14
# Estimated Total Size (MB): 3019.10
# ===================================================================================================================
# ===================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #
# ===================================================================================================================
# BrainTumorCNN                            [64, 3, 224, 224]         [64, 4]                   --
# ├─Sequential: 1-1                        [64, 3, 224, 224]         [64, 128, 28, 28]         --
# │    └─Conv2d: 2-1                       [64, 3, 224, 224]         [64, 32, 224, 224]        896
# │    └─BatchNorm2d: 2-2                  [64, 32, 224, 224]        [64, 32, 224, 224]        64
# │    └─ReLU: 2-3                         [64, 32, 224, 224]        [64, 32, 224, 224]        --
# │    └─MaxPool2d: 2-4                    [64, 32, 224, 224]        [64, 32, 112, 112]        --
# │    └─Conv2d: 2-5                       [64, 32, 112, 112]        [64, 64, 112, 112]        18,496
# │    └─BatchNorm2d: 2-6                  [64, 64, 112, 112]        [64, 64, 112, 112]        128
# │    └─ReLU: 2-7                         [64, 64, 112, 112]        [64, 64, 112, 112]        --
# │    └─MaxPool2d: 2-8                    [64, 64, 112, 112]        [64, 64, 56, 56]          --
# │    └─Conv2d: 2-9                       [64, 64, 56, 56]          [64, 128, 56, 56]         73,856
# │    └─ReLU: 2-10                        [64, 128, 56, 56]         [64, 128, 56, 56]         --
# │    └─BatchNorm2d: 2-11                 [64, 128, 56, 56]         [64, 128, 56, 56]         256
# │    └─MaxPool2d: 2-12                   [64, 128, 56, 56]         [64, 128, 28, 28]         --
# ├─Sequential: 1-2                        [64, 128, 28, 28]         [64, 4]                   --
# │    └─Flatten: 2-13                     [64, 128, 28, 28]         [64, 100352]              --
# │    └─Linear: 2-14                      [64, 100352]              [64, 256]                 25,690,368
# │    └─ReLU: 2-15                        [64, 256]                 [64, 256]                 --
# │    └─Dropout: 2-16                     [64, 256]                 [64, 256]                 --
# │    └─Linear: 2-17                      [64, 256]                 [64, 4]                   1,028
# ===================================================================================================================
# Total params: 25,785,092
# Trainable params: 25,785,092
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 34.19
# ===================================================================================================================
# Input size (MB): 38.54
# Forward/backward pass size (MB): 2877.43
# Params size (MB): 103.14
# Estimated Total Size (MB): 3019.10
# ===================================================================================================================
